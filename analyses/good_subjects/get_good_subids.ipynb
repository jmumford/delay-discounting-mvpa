# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %load_ext autoreload
# %autoreload 2
from delay_discounting_mvpa.config_loader import load_config
from delay_discounting_mvpa.design_utils import create_design_matrices
from delay_discounting_mvpa.io_utils import get_subids, load_tsv_data, resolve_file

# %% [markdown]
# # Purpose
#
# This code generates subject_exclusion_summaries.csv, which describes:
#
# 1. Subjects to omit (with reasons)
# 2. Subjects to include (good subjects)
#
# Subjects are excluded based on the following hierarchy of criteria:
#
# * **Behavioral data missing**
# * **Previously defined exclusion criteria** (from `BIDS/suggested_exclusions.csv`)
# * **Always responded with the same choice**
# * **BOLD data missing**
# * **Trial onset beyond the scan duration**:
#     * max onset = 870.99 s, scan duration = 724.20 s
#     * max onset = 735.04 s, scan duration = 724.20 s
#
# > Note: Because this is a hierarchical system, if a subject was excluded for one criterion (e.g., always responding with the same choice), later criteria (e.g., missing BOLD data) were not checked.
#
# All of this logic is implemented in `create_design_matrices()`. The output of that function has been used to create a CSV (`subject_status.csv`) that can be referenced when running analyses.
#
# ## Summary of subject counts
#
# | Reason                                           | Number of subjects |
# |-------------------------------------------------|-----------------|
# | Passed all checks                                | 77              |
# | Behavioral data missing                          | 7               |
# | Met exclusion criteria (`suggested_exclusion.csv`) | 13              |
# | Always gave the same response                    | 9               |
# | Onset beyond the scan duration                   | 2               |

# %%
config_file = '/oak/stanford/groups/russpold/data/uh2/aim1/analysis_code/delay_discounting_mvpa/configs/config.yaml'
cfg = load_config(config_file)

# %%
tr = cfg.tr
subids = get_subids(cfg)
hp_filter_cutoff = 1 / 450


model_subids, bold_paths, design_matrices, status_df = create_design_matrices(
    cfg, subids, tr, hp_filter_cutoff
)
# Out:
# Processing s061...
# Processing s130...
# Processing s144...
# Skipping s144 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s144_discountFix_events.tsv)
# Processing s172...
# Processing s192...
# Processing s234...
# Processing s251...
# Processing s358...
# Processing s373...
# Skipping s373 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s445...
# Skipping s445 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks, MRIQC_fail)
# Processing s465...
# Skipping s465 (singular response: 0 smaller sooner / 120 larger later)
# Processing s471...
# Processing s483...
# Processing s491...
# Skipping s491: onset beyond scan duration: max onset=870.99s, scan duration=724.20s
# Processing s495...
# Skipping s495: onset beyond scan duration: max onset=735.04s, scan duration=724.20s
# Processing s497...
# Processing s499...
# Skipping s499 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s499_discountFix_events.tsv)
# Processing s512...
# Processing s513...
# Skipping s513 (singular response: 114 smaller sooner / 0 larger later)
# Processing s518...
# Processing s519...
# Skipping s519 (singular response: 0 smaller sooner / 120 larger later)
# Processing s524...
# Processing s525...
# Processing s526...
# Processing s533...
# Skipping s533 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s533_discountFix_events.tsv)
# Processing s541...
# Processing s546...
# Processing s548...
# Processing s549...
# Processing s553...
# Skipping s553 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s554...
# Processing s555...
# Processing s556...
# s556: removing 1 trial(s) with negative onset(s)
# Processing s557...
# Processing s558...
# Skipping s558 (singular response: 0 smaller sooner / 120 larger later)
# Processing s561...
# Processing s567...
# Processing s568...
# s568: removing 1 trial(s) with negative onset(s)
# Processing s570...
# Processing s572...
# Skipping s572 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s572_discountFix_events.tsv)
# Processing s573...
# Processing s574...
# Processing s577...
# Processing s579...
# Processing s581...
# Processing s582...
# Skipping s582 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s583...
# Processing s584...
# Processing s585...
# Processing s586...
# Skipping s586 (singular response: 120 smaller sooner / 0 larger later)
# Processing s587...
# Processing s588...
# Skipping s588 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks, MRIQC_fail)
# Processing s589...
# Processing s590...
# Processing s591...
# Processing s592...
# Skipping s592 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s593...
# Processing s594...
# Processing s595...
# Processing s596...
# Processing s597...
# Processing s598...
# Skipping s598 (singular response: 0 smaller sooner / 120 larger later)
# Processing s601...
# Processing s602...
# Processing s603...
# Skipping s603 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s603_discountFix_events.tsv)
# Processing s604...
# Processing s605...
# Skipping s605 (singular response: 0 smaller sooner / 120 larger later)
# Processing s606...
# Processing s607...
# Skipping s607 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s608...
# Skipping s608 (singular response: 0 smaller sooner / 120 larger later)
# Processing s609...
# Processing s610...
# Processing s611...
# Processing s612...
# Processing s613...
# Processing s614...
# Processing s615...
# Processing s616...
# Processing s617...
# Processing s618...
# Processing s619...
# Skipping s619 (met suggested_exclusion.csv criteria: MRIQC_fail)
# Processing s621...
# Processing s622...
# Processing s623...
# Skipping s623 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s624...
# Processing s626...
# Processing s627...
# Processing s628...
# Processing s629...
# Processing s631...
# Processing s633...
# Processing s634...
# Processing s635...
# Processing s636...
# Processing s637...
# Skipping s637 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)
# Processing s638...
# Processing s639...
# Skipping s639 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s639_discountFix_events.tsv)
# Processing s640...
# Skipping s640 (behav missing: No files found for 'behav' with pattern: /oak/stanford/groups/russpold/data/uh2/aim1/behavioral_data/event_files/s640_discountFix_events.tsv)
# Processing s641...
# Processing s642...
# Processing s643...
# Processing s644...
# Processing s645...
# Processing s646...
# Skipping s646 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks, missing_beh_data)
# Processing s647...
# Skipping s647 (met suggested_exclusion.csv criteria: missing_beh_data)
# Processing s648...
# Processing s649...
# Skipping s649 (singular response: 0 smaller sooner / 117 larger later)
# Processing s650...
# Skipping s650 (met suggested_exclusion.csv criteria: missing_more_than_half_the_tasks)

# %%
status_df[['conclusion', 'details']] = status_df['reason'].str.split(
    ':', n=1, expand=True
)

# Optional: strip whitespace
status_df['conclusion'] = status_df['conclusion'].str.strip()
status_df['details'] = status_df['details'].str.strip()

# For rows with no colon, 'details' will be NaN. You can replace with empty string if desired:
status_df['details'] = status_df['details'].fillna('')

status_df = status_df.drop(columns=['reason'])

# %%
np.unique(status_df['conclusion'], return_counts=True)
# Out:
# (array(['Passed all checks', 'behav missing',
#         'met suggested_exclusion.csv criteria',
#         'onset beyond scan duration', 'singular response'], dtype=object),
#  array([77,  7, 13,  2,  9]))

# %%
status_df.to_csv('subject_status.csv', index=False)

# %%
# more useful for slurm jobs to have a simple text file with the good subjects
good_subids = status_df.loc[status_df['include'], 'sub_id']
good_subids.to_csv('good_subids.txt', index=False, header=False)
